# %%
import tensorflow as tf
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import scipy.interpolate as interp
import keras 
from keras import layers
import hickle as hkl
from keras.callbacks import History 
history = History()
import time

# %%
#load the model and dataset
dataset = hkl.load('datasetshort.hkl')
modelv2rw = keras.models.load_model('model_v2_rw.h5')
np.shape(dataset)
# Out:
# (12000, 6, 1000)

# %%
#load the test tracks
testtracks = hkl.load('testtracks.hkl')
#normalization function for the circuits
def normalizecircuit(circuit):
    jcircuit = circuit-circuit.min()
    normcircuit = jcircuit/jcircuit.max()
    return normcircuit
ntesttracks = normalizecircuit(testtracks)

# %%
validationtest = modelv2rw(ntesttracks[:,0:4])

# %%
#check the model with the training dataset and calculate the the output time.
n = 1
start = time.time()
elapsedtrack = np.array([normalizecircuit(np.array(testtracks[n]))])
result = modelv2rw(elapsedtrack[:,0:4])
end = time.time()
elapsedtime = end-start
for i in [0,2,4]:
        plt.plot(elapsedtrack[0,i],elapsedtrack[0,i+1])
plt.plot(result[0,0],result[0,1])
print(elapsedtime," seconds")
# Out:
# 0.02678370475769043  seconds

# %%
#generate graphs
for n in [0,1,2,3,4]:
    start = time.time()
    elapsedtrack = np.array([normalizecircuit(np.array(testtracks[n]))])
    result = modelv2rw(elapsedtrack[:,0:4])
    end = time.time()
    elapsedtime = end-start
    for i in [0,2,4]:
         plt.plot(elapsedtrack[0,i],elapsedtrack[0,i+1])
    plt.plot(result[0,0],result[0,1])
    plt.savefig('results/circuit'+str(n)+'modelv2_rw.png')
    plt.clf()
    print(elapsedtime)
# Out:
# 0.021824359893798828
# 0.01587224006652832
# 0.01735997200012207
# 0.021353721618652344
# 0.016870975494384766
