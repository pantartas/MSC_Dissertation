# %%
import tensorflow as tf
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
import scipy.interpolate as interp
import keras 
from keras import layers
import hickle as hkl
from keras.callbacks import History 
history = History()
import time

# %%
#load the model and dataset
dataset = hkl.load('datasetshort.hkl')
modelv6rw = keras.models.load_model('model_v6_rw.h5')
np.shape(dataset)
# Out:
# (12000, 6, 1000)

# %%
#load the test tracks
testtracks = hkl.load('testtracks.hkl')
#normalization function for the circuits
def normalizecircuit(circuit):
    jcircuit = circuit-circuit.min()
    normcircuit = jcircuit/jcircuit.max()
    return normcircuit
ntesttracks = normalizecircuit(testtracks)

# %%
validationtest = modelv6rw(ntesttracks[:,0:4])

# %%
#check the model with the training dataset and calculate the the output time.
n = 1
start = time.time()
elapsedtrack = np.array([normalizecircuit(np.array(testtracks[n]))])
result = modelv6rw(elapsedtrack[:,0:4])
end = time.time()
elapsedtime = end-start
for i in [0,2,4]:
        plt.plot(elapsedtrack[0,i],elapsedtrack[0,i+1])
plt.plot(result[0,0],result[0,1])
print(elapsedtime," seconds")
# Out:
# 0.025295019149780273  seconds

# %%
#generate graphs
for n in [0,1,2,3,4]:
    start = time.time()
    elapsedtrack = np.array([normalizecircuit(np.array(testtracks[n]))])
    result = modelv6rw(elapsedtrack[:,0:4])
    end = time.time()
    elapsedtime = end-start
    for i in [0,2,4]:
         plt.plot(elapsedtrack[0,i],elapsedtrack[0,i+1])
    plt.plot(result[0,0],result[0,1])
    plt.savefig('results/circuit'+str(n)+'modelv6_rw.png')
    plt.clf()
    print(elapsedtime)
# Out:
# 0.030251264572143555
# 0.02236318588256836
# 0.020832300186157227
# 0.024811506271362305
# 0.022320032119750977
